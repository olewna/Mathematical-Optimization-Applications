# %% [markdown]
# # Trace, determinant, rank of square matrix

# %%
using JuMP
using SDPA
using SCIP
using LinearAlgebra

# %% [markdown]
# ## Random matrix example

# %%
A = [6 7 9; 
    12 1 4; 
    5 6 3]
# Out:
# 3×3 Matrix{Int64}:
#   6  7  9
#  12  1  4
#   5  6  3

# %% [markdown]
# ### trace

# %%
tr(A)
# Out:
# 10

# %% [markdown]
# ### determinant

# %%
det(A)
# Out:
# 364.99999999999994

# %% [markdown]
# ### rank

# %%
rank(A)
# Out:
# 3

# %% [markdown]
# ### eigenvalues

# %%
eigvals(A)
# Out:
# 3-element Vector{ComplexF64}:
#  -4.041863136993129 - 1.961437124767069im
#  -4.041863136993129 + 1.961437124767069im
#  18.083726273986244 + 0.0im

# %% [markdown]
# ### eigenvectors

# %%
eigvecs(A)
# Out:
# 3×3 Matrix{ComplexF64}:
#    0.17547+0.224991im    0.17547-0.224991im  0.675177+0.0im
#  -0.786555-0.0im       -0.786555+0.0im       0.580752+0.0im
#   0.465016-0.289278im   0.465016+0.289278im  0.454821+0.0im

# %% [markdown]
# ## Symetric matrix example

# %%
B = [1 2 0;
    2 3 0
    0 0 5]
# Out:
# 3×3 Matrix{Int64}:
#  1  2  0
#  2  3  0
#  0  0  5

# %%
B' #symetry
# Out:
# 3×3 adjoint(::Matrix{Int64}) with eltype Int64:
#  1  2  0
#  2  3  0
#  0  0  5

# %% [markdown]
# ### eigenvalues

# %%
eigvals(B)
# Out:
# 3-element Vector{Float64}:
#  -0.2360679774997897
#   4.23606797749979
#   5.0

# %% [markdown]
# ### eigenvectors

# %%
eigvecs(B)
# Out:
# 3×3 Matrix{Float64}:
#   0.850651  0.525731  0.0
#  -0.525731  0.850651  0.0
#   0.0       0.0       1.0

# %% [markdown]
# ## Orthogonal martix example

# %%
C = [1 0 0;
    0 0 -1;
    0 1 0]
# Out:
# 3×3 Matrix{Int64}:
#  1  0   0
#  0  0  -1
#  0  1   0

# %%
C'
# Out:
# 3×3 adjoint(::Matrix{Int64}) with eltype Int64:
#  1   0  0
#  0   0  1
#  0  -1  0

# %%
C * C'
# Out:
# 3×3 Matrix{Int64}:
#  1  0  0
#  0  1  0
#  0  0  1

# %% [markdown]
# ### eigenvalues

# %%
eigvals(C)
# Out:
# 3-element Vector{ComplexF64}:
#  0.0 - 1.0im
#  0.0 + 1.0im
#  1.0 + 0.0im

# %% [markdown]
# ### eigenvectors

# %%
eigvecs(C)
# Out:
# 3×3 Matrix{ComplexF64}:
#       0.0-0.0im            0.0+0.0im       1.0+0.0im
#  0.707107-0.0im       0.707107+0.0im       0.0+0.0im
#       0.0+0.707107im       0.0-0.707107im  0.0+0.0im

# %% [markdown]
# ## Decomposition of matrix in basis $E_{ij}$

# %%
A
# Out:
# 3×3 Matrix{Int64}:
#   6  7  9
#  12  1  4
#   5  6  3

# %%
m, n = size(A)

# Create the E_{ij} basis matrices
E = [ [ (i == p && j == q ? 1 : 0) for i in 1:m, j in 1:n ] for p in 1:m, q in 1:n ]


# Decompose A in that basis
decomposition = [(A[p, q], E[p, q]) for p in 1:m, q in 1:n]

# Print results
for (coeff, basis_matrix) in decomposition
    println("Coefficient: $coeff")
    display(basis_matrix)
end
# Out:
# Coefficient: 6
# 3×3 Matrix{Int64}:
#  1  0  0
#  0  0  0
#  0  0  0
# Coefficient: 12
# 3×3 Matrix{Int64}:
#  0  0  0
#  1  0  0
#  0  0  0
# Coefficient: 5
# 3×3 Matrix{Int64}:
#  0  0  0
#  0  0  0
#  1  0  0
# Coefficient: 7
# 3×3 Matrix{Int64}:
#  0  1  0
#  0  0  0
#  0  0  0
# Coefficient: 1
# 3×3 Matrix{Int64}:
#  0  0  0
#  0  1  0
#  0  0  0
# Coefficient: 6
# 3×3 Matrix{Int64}:
#  0  0  0
#  0  0  0
#  0  1  0
# Coefficient: 9
# 3×3 Matrix{Int64}:
#  0  0  1
#  0  0  0
#  0  0  0
# Coefficient: 4
# 3×3 Matrix{Int64}:
#  0  0  0
#  0  0  1
#  0  0  0
# Coefficient: 3
# 3×3 Matrix{Int64}:
#  0  0  0
#  0  0  0
#  0  0  1

# %% [markdown]
# ### LL-decomposition

# %%
D = [4 2 2;
     2 2 1;
     2 1 3]
# Out:
# 3×3 Matrix{Int64}:
#  4  2  2
#  2  2  1
#  2  1  3

# %%
F = cholesky(D)
L = F.L
# Out:
# 3×3 LowerTriangular{Float64, Matrix{Float64}}:
#  2.0   ⋅    ⋅
#  1.0  1.0   ⋅
#  1.0  0.0  1.41421

# %%
L * L'
# Out:
# 3×3 Matrix{Float64}:
#  4.0  2.0  2.0
#  2.0  2.0  1.0
#  2.0  1.0  3.0

# %% [markdown]
# ## Spectral decomposition

# %%
E = [1 0;
    1 3]
# Out:
# 2×2 Matrix{Int64}:
#  1  0
#  1  3

# %%
eig_val_E = eigvals(E)
# Out:
# 2-element Vector{Float64}:
#  1.0
#  3.0

# %%
eig_vec_E = eigvecs(E)
# Out:
# 2×2 Matrix{Float64}:
#   0.894427  0.0
#  -0.447214  1.0

# %%
Diagonal(eig_val_E)
# Out:
# 2×2 Diagonal{Float64, Vector{Float64}}:
#  1.0   ⋅
#   ⋅   3.0

# %%
eig_vec_E * Diagonal(eig_val_E) * eig_vec_E'
# Out:
# 2×2 Matrix{Float64}:
#   0.8  -0.4
#  -0.4   3.2

# %%
Diagonal(eig_val_E) * eig_vec_E * eig_vec_E'
# Out:
# 2×2 Matrix{Float64}:
#   0.8  -0.4
#  -1.2   3.6

# %% [markdown]
# ## Gram matrix

# %%
u1 = [1; 0; 1]
# Out:
# 3-element Vector{Int64}:
#  1
#  0
#  1

# %%
u2 = [0; 1; 1]
# Out:
# 3-element Vector{Int64}:
#  0
#  1
#  1

# %%
u3 = [1; 1; 0]
# Out:
# 3-element Vector{Int64}:
#  1
#  1
#  0

# %%
U = [1 0 1; 0 1 1; 1 1 0]
# Out:
# 3×3 Matrix{Int64}:
#  1  0  1
#  0  1  1
#  1  1  0

# %%
G = U * U'
# Out:
# 3×3 Matrix{Int64}:
#  2  1  1
#  1  2  1
#  1  1  2

# %% [markdown]
# ## $A, B \geq 0 => A * B \geq 0 $

# %%
A
# Out:
# 3×3 Matrix{Int64}:
#   6  7  9
#  12  1  4
#   5  6  3

# %%
B
# Out:
# 3×3 Matrix{Int64}:
#  1  2  0
#  2  3  0
#  0  0  5

# %%
A_cho = cholesky(A)
L_A = A_cho.L
# Out:
# PosDefException: matrix is not Hermitian; Factorization failed.
#
# Stacktrace:
#  [1] checkpositivedefinite(info::Int64)
#    @ LinearAlgebra C:\Users\olewn\.julia\juliaup\julia-1.11.7+0.x64.w64.mingw32\share\julia\stdlib\v1.11\LinearAlgebra\src\factorization.jl:68
#  [2] #cholesky!#164
#    @ C:\Users\olewn\.julia\juliaup\julia-1.11.7+0.x64.w64.mingw32\share\julia\stdlib\v1.11\LinearAlgebra\src\cholesky.jl:298 [inlined]
#  [3] cholesky! (repeats 2 times)
#    @ C:\Users\olewn\.julia\juliaup\julia-1.11.7+0.x64.w64.mingw32\share\julia\stdlib\v1.11\LinearAlgebra\src\cholesky.jl:295 [inlined]
#  [4] _cholesky
#    @ C:\Users\olewn\.julia\juliaup\julia-1.11.7+0.x64.w64.mingw32\share\julia\stdlib\v1.11\LinearAlgebra\src\cholesky.jl:411 [inlined]
#  [5] cholesky(A::Matrix{Int64}, ::NoPivot; check::Bool)
#    @ LinearAlgebra C:\Users\olewn\.julia\juliaup\julia-1.11.7+0.x64.w64.mingw32\share\julia\stdlib\v1.11\LinearAlgebra\src\cholesky.jl:401
#  [6] cholesky
#    @ C:\Users\olewn\.julia\juliaup\julia-1.11.7+0.x64.w64.mingw32\share\julia\stdlib\v1.11\LinearAlgebra\src\cholesky.jl:401 [inlined]
#  [7] cholesky(A::Matrix{Int64})
#    @ LinearAlgebra C:\Users\olewn\.julia\juliaup\julia-1.11.7+0.x64.w64.mingw32\share\julia\stdlib\v1.11\LinearAlgebra\src\cholesky.jl:401
#  [8] top-level scope
#    @ In[149]:1
